# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\shris\Downloads\archive\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df['Attrition'].value_counts()
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
df['Attrition'].value_counts().plot(kind='bar', title='Employee Attrition',grid=True)
# Out:
# <Axes: title={'center': 'Employee Attrition'}, xlabel='Attrition'>

# %%
df.groupby('Attrition')['Age'].mean()
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
df.groupby('Attrition')['MonthlyIncome'].mean()
# Out:
# Attrition
# No     6832.739659
# Yes    4787.092827
# Name: MonthlyIncome, dtype: float64

# %%
pd.crosstab(df['Department'], df['Attrition'], normalize='index')
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
pd.crosstab(df['OverTime'], df['Attrition'], normalize='index')
# Out:
# Attrition        No       Yes
# OverTime
# No         0.895636  0.104364
# Yes        0.694712  0.305288

# %%
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
x= df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
x = pd.get_dummies(X, drop_first=True)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

lr = LogisticRegression(
    max_iter=500,
    solver='liblinear'
)

lr.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=500, solver='liblinear')

# %%
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score

y_pred = lr.predict(X_test)
y_prob = lr.predict_proba(X_test)[:,1]

accuracy_score(y_test, y_pred)
recall_score(y_test, y_pred)
roc_auc_score(y_test, y_prob)
# Out:
# C:\Users\shris\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# C:\Users\shris\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# 0.5

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_prob_rf = rf.predict_proba(X_test)[:,1]
roc_auc_score(y_test, y_prob_rf)
# Out:
# 0.7501256913021619

# %%
importance = pd.Series(rf.feature_importances_, index=X.columns)
importance.sort_values(ascending=False).head(10)
# Out:
# MonthlyIncome           0.077561
# Age                     0.060162
# OverTime_Yes            0.058734
# DailyRate               0.049107
# MonthlyRate             0.048652
# DistanceFromHome        0.046978
# TotalWorkingYears       0.046865
# HourlyRate              0.044677
# YearsAtCompany          0.040930
# YearsWithCurrManager    0.034347
# dtype: float64

# %%
attrition_rate = df['Attrition'].mean() * 100
avg_age = df[df['Attrition']==1]['Age'].mean()
attrition_rate
# Out:
# np.float64(16.122448979591837)

# %%
avg_age
# Out:
# np.float64(33.607594936708864)

# %%
avg_salary_leavers = df[df['Attrition'] == 1]['MonthlyIncome'].mean()
avg_salary_leavers
# Out:
# np.float64(4787.0928270042195)

# %%
attrition_by_dept = (
    df.groupby('Department')['Attrition']
      .mean()
      .sort_values(ascending=False) * 100
)

attrition_by_dept
# Out:
# Department
# Sales                     20.627803
# Human Resources           19.047619
# Research & Development    13.839750
# Name: Attrition, dtype: float64

# %%
attrition_by_overtime = (
    df.groupby('OverTime')['Attrition']
      .mean() * 100
)

attrition_by_overtime
# Out:
# OverTime
# No     10.436433
# Yes    30.528846
# Name: Attrition, dtype: float64

# %%
kpi_df = pd.DataFrame({
    'KPI': [
        'Attrition Rate (%)',
        'Avg Age of Leavers',
        'Avg Salary of Leavers'
    ],
    'Value': [
        attrition_rate,
        avg_age,
        avg_salary_leavers
    ]
})

kpi_df
# Out:
#                      KPI        Value
# 0     Attrition Rate (%)    16.122449
# 1     Avg Age of Leavers    33.607595
# 2  Avg Salary of Leavers  4787.092827

# %%
attrition_by_overtime.plot(kind='bar', title='Attrition by Overtime',grid=True,rot=0,alpha=0.6,edgecolor='black')
# Out:
# <Axes: title={'center': 'Attrition by Overtime'}, xlabel='OverTime'>

# %%
attrition_by_dept.plot(kind='bar', title='Attrition by Department',grid=True,rot=0,alpha=0.6,edgecolor='black')
# Out:
# <Axes: title={'center': 'Attrition by Department'}, xlabel='Department'>
